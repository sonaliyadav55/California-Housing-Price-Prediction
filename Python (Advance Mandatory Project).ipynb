# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df= pd.read_excel('C:\\Users\\God\\Downloads\\2198208-housing_(1).xlsx')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# # COLOUMNS:
# 1.longitude: A measurement of distance of house is located horizontally
#  it comes under numerical data type, i.e.,Continuous data.
#
# 2.latitude: A measurement of distance of house is located vertically.
#
# 3.housing_median_age: It is Median age of a house.Statistically it is of quantitative datatype,i.e.,Continuous data.
#
# 4.total_rooms: Total number of rooms.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 5.total_bedrooms: Total number of bedrooms within a block.
#
# 6.population: Total number of people residing within a block. it is discrete data.
#
# 7.households: Total number of households..  quantitative data type,i.e.,discrete data.
#
# 8.median_income: Median income of households within a block of houses.. It comes under continuous data.
#
# 9.median_house_value: Median house value for households. It comes under continuous data.
#
# 10.Ocean_proximity: Location of the house with respect to ocean. it comes under categorical data.

# %% [markdown]
# 1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
df=df['median_income'].mean()
df

#mean() give the average value of 'median_income'.
# Out:
# 3.8706710029069766

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df.hist(bins=70)
plt.show()

# %% [raw]
# # QUESTION 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
plt.hist(df['housing_median_age'],color='red')
plt.xlabel('housing_median_age')
plt.ylabel('')
plt.title('HOUSING_MEDIAN_AGE PLOT')
plt.show()

# %% [markdown]
# This housing_median_age histogram plot is Distributed  symmetric.

# %% [markdown]
# QUESTION 3. Show with the help of visualization, how median_income and median_house_values are related?

# %%
import seaborn as sns
sns.scatterplot(x="median_house_value",y="median_income",data=df,facecolor='red')
plt.show()

# %% [markdown]
# From the above visualisation it is to be analysed that with an increase in the median_house_value there is also an increase in the median income.While,an outlier is present in median_house_value which is shown in the fig.Therefore,median_house_value is directly proportional to median income.

# %% [markdown]
# QUESTION 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
df['total_bedrooms'].isnull()

# missing values are identified by using isnull()method.This missing values are identified in the column 'total_bedrooms'.
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: total_bedrooms, Length: 20640, dtype: bool

# %%
df[df.isnull().any(axis=1)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                  47         1256             NaN
# 341      -122.17     37.75                  38          992             NaN
# 538      -122.28     37.78                  29         5154             NaN
# 563      -122.24     37.75                  45          891             NaN
# 696      -122.10     37.69                  41          746             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                  18         3620             NaN
# 20268    -119.18     34.19                  19         2393             NaN
# 20372    -118.88     34.17                  15         4260             NaN
# 20460    -118.75     34.29                  17         5512             NaN
# 20484    -118.72     34.28                  17         3051             NaN
#
# ...

# %%
drop_data= df.dropna(subset=['total_bedrooms'])
drop_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# QUESTION 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
mean_value= df['total_bedrooms'].mean
mean_value
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0         129.0
# 1        1106.0
# 2         190.0
# 3         235.0
# 4         280.0
#           ...
# 20635     374.0
# 20636     150.0
# 20637     485.0
# 20638     409.0
# 20639     616.0
# Name: total_bedrooms, Length: 20640, dtype: object>

# %%
df['total_bedrooms']= df['total_bedrooms'].fillna(mean_value)
df['total_bedrooms']
# Out:
# 0         129.0
# 1        1106.0
# 2         190.0
# 3         235.0
# 4         280.0
#           ...
# 20635     374.0
# 20636     150.0
# 20637     485.0
# 20638     409.0
# 20639     616.0
# Name: total_bedrooms, Length: 20640, dtype: object

# %% [markdown]
# QUESTION 6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

# %%
df['longitude'].median()
# Out:
# 34.26

# %%
df['latitude'].median()
# Out:
# 34.26

# %%
df['housing_median_age'].median()
# Out:
# 29.0

# %%
df['total_rooms'].median()
# Out:
# 2127.0

# %%
df['population'].median()
# Out:
# 1166.0

# %%
df['households'].median()
# Out:
# 409.0

# %%
df['median_income'].median()
# Out:
# 3.5347999999999997

# %%
df['median_house_value'].median()
# Out:
# 179700.0

# %% [markdown]
# QUESTION 7. Plot latitude versus longitude and explain your observations.

# %%
sns.scatterplot(x='latitude',y='longitude',data=df)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# From the above plot, noted that with an decrease in longitude,latitude is increased.
#
# latitude and longitude are not dependent on each other.From this we can say that longitude is inversely proportional to latitude.

# %% [markdown]
# QUESTION 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
new = df.loc[df["ocean_proximity"]=="NEAR OCEAN"] 
new 

# loc  is used to select rows and columns by Names.
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %% [markdown]
# QUESTION 9.Find the mean and median of the median income for the data set created in question 8.

# %%
new['median_income'].mean()

#mean() gives the averages of the data. it is used for numerical data.
# Out:
# 4.0057848006019565

# %%
new['median_income'].median()
# Out:
# 3.64705

# %% [markdown]
# QUESTION 10.Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %% [markdown]
#  CONCLUSION:
#
# 1. outliers are present for housing_median_age and median_house_value.
#
# 2.plot between latitude and longitude is inversely proportional to each other as within increase in latitude,there is decrease in longitude.Therefore ,it has a negative correlation.
#
#
# 3.Housing_median_age is symmetric. .
#
# 4.plot between median_income vs median_house_values is directly proportional to each other.
